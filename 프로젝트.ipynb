# %%
from selenium.webdriver import Chrome
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup
import time
import requests
import re
import csv
import requests
import pandas as pd
import os
import csv
chrome = Chrome()

seoul_list=[2,8,15,22,25,33,42,47,54,55,63,72,78,79,85,96,101,105,109,120,125,131,138,143,148,154,158,168,173,178,186,189,194,199,208,215,222,223,225]
def url_move(seoul_list):
    url = f"https://www.kleague.com/match.do?year=2022&leagueId=1&gameId={seoul_list}&meetSeq=1&startTabNum=1"
    chrome.get(url)
def avg(number):
    result = 0
    result_2 = 0
    for num in range(len(number)):
        if num < 11:
            result += float(number[num][0:3])
        else:
            result_2 += float(number[num][0:3])            
    result = round(result/11,1)
    result_2 = round(result_2/11,1)
    return result , result_2

url_move(seoul_list[0])
btn = chrome.find_element(by='xpath', value='/html/body/div[2]/div/ul/li[2]')
btn.click()
time.sleep(1)
response_1 = chrome.page_source
number= BeautifulSoup(response_1).find('div', {'class':'formation'}).text.split()
# 왼쪽 홈팀 오른쪽 원정팀
Havg_1 = avg(number)[0]
Aavg_1 = avg(number)[1]
Havg_1
Aavg_1

response_1 = chrome.page_source
score= BeautifulSoup(response_1).find('div', {'class':'score campton'})
S1_1 = score.text[0:1]
S1_2 = score.text[2:3]
response_2 = chrome.page_source
myform = BeautifulSoup(response_2).find('div', {'class':'btn-cont'})
H1_1 = (myform.get_text('i').split('i')[1])
A1_1 = (myform.get_text('i').split('i')[3]) #점유율
H1_2 = (myform.get_text('i').split('i')[4])
A1_2 = (myform.get_text('i').split('i')[6]) #슈팅
H1_3 = (myform.get_text('i').split('i')[7])
A1_3 = (myform.get_text('i').split('i')[9]) # 유효슈팅
H1_4 = (myform.get_text('i').split('i')[10])
A1_4 = (myform.get_text('i').split('i')[12]) # 파울
H1_5 = (myform.get_text('i').split('i')[13])
A1_5 = (myform.get_text('i').split('i')[15]) # 경고
H1_6 = (myform.get_text('i').split('i')[16])
A1_6 = (myform.get_text('i').split('i')[18]) # 퇴장
H1_7 = (myform.get_text('i').split('i')[19])
A1_7 = (myform.get_text('i').split('i')[22]) #퇴장(경고누적)
H1_8 = (myform.get_text('i').split('i')[23])
A1_8 = (myform.get_text('i').split('i')[25]) # 코너킥
H1_9 = (myform.get_text('i').split('i')[26])
A1_9 = (myform.get_text('i').split('i')[28]) # 프리킥
H1_10 = (myform.get_text('i').split('i')[29])
A1_10 = (myform.get_text('i').split('i')[31]) # 오프사이드
# 1라운드 #홈팀 대구 원정팀 서울 데이터

# %%
url_move(seoul_list[1])
btn = chrome.find_element(by='xpath', value='/html/body/div[2]/div/ul/li[2]')
btn.click()
time.sleep(1)
response_1 = chrome.page_source
number= BeautifulSoup(response_1).find('div', {'class':'formation'}).text.split()
# 왼쪽 홈팀 오른쪽 원정팀
Havg_2 = avg(number)[0]
Aavg_2 = avg(number)[1]
Havg_2
Aavg_2
response_1 = chrome.page_source
score= BeautifulSoup(response_1).find('div', {'class':'score campton'})
S2_1 = score.text[0:1]
S2_2 = score.text[2:3]
response_2 = chrome.page_source
myform = BeautifulSoup(response_2).find('div', {'class':'btn-cont'})
H2_1 = (myform.get_text('i').split('i')[1])
A2_1 = (myform.get_text('i').split('i')[3]) #점유율
H2_2 = (myform.get_text('i').split('i')[4])
A2_2 = (myform.get_text('i').split('i')[6]) #슈팅
H2_3 = (myform.get_text('i').split('i')[7])
A2_3 = (myform.get_text('i').split('i')[9]) # 유효슈팅
H2_4 = (myform.get_text('i').split('i')[10])
A2_4 = (myform.get_text('i').split('i')[12]) # 파울
H2_5 = (myform.get_text('i').split('i')[13])
A2_5 = (myform.get_text('i').split('i')[15]) # 경고
H2_6 = (myform.get_text('i').split('i')[16])
A2_6 = (myform.get_text('i').split('i')[18]) # 퇴장
H2_7 = (myform.get_text('i').split('i')[19])
A2_7 = (myform.get_text('i').split('i')[22]) #퇴장(경고누적)
H2_8 = (myform.get_text('i').split('i')[23])
A2_8 = (myform.get_text('i').split('i')[25]) # 코너킥
H2_9 = (myform.get_text('i').split('i')[26])
A2_9 = (myform.get_text('i').split('i')[28]) # 프리킥
H2_10 = (myform.get_text('i').split('i')[29])
A2_10 = (myform.get_text('i').split('i')[31]) # 오프사이드
# 2라운드 #홈팀 인천 원정팀 서울 데이터

# %%
url_move(seoul_list[2])
btn = chrome.find_element(by='xpath', value='/html/body/div[2]/div/ul/li[2]')
btn.click()
time.sleep(1)
response_1 = chrome.page_source
number= BeautifulSoup(response_1).find('div', {'class':'formation'}).text.split()
# 왼쪽 홈팀 오른쪽 원정팀
Havg_3 = avg(number)[0]
Aavg_3 = avg(number)[1]
Havg_3
Aavg_3
response_1 = chrome.page_source
score= BeautifulSoup(response_1).find('div', {'class':'score campton'})
S3_1 = score.text[0:1]
S3_2 = score.text[2:3]
response_2 = chrome.page_source
myform = BeautifulSoup(response_2).find('div', {'class':'btn-cont'})
H3_1 = (myform.get_text('i').split('i')[1])
A3_1 = (myform.get_text('i').split('i')[3]) #점유율
H3_2 = (myform.get_text('i').split('i')[4])
A3_2 = (myform.get_text('i').split('i')[6]) #슈팅
H3_3 = (myform.get_text('i').split('i')[7])
A3_3 = (myform.get_text('i').split('i')[9]) # 유효슈팅
H3_4 = (myform.get_text('i').split('i')[10])
A3_4 = (myform.get_text('i').split('i')[12]) # 파울
H3_5 = (myform.get_text('i').split('i')[13])
A3_5 = (myform.get_text('i').split('i')[15]) # 경고
H3_6 = (myform.get_text('i').split('i')[16])
A3_6 = (myform.get_text('i').split('i')[18]) # 퇴장
H3_7 = (myform.get_text('i').split('i')[19])
A3_7 = (myform.get_text('i').split('i')[22]) #퇴장(경고누적)
H3_8 = (myform.get_text('i').split('i')[23])
A3_8 = (myform.get_text('i').split('i')[25]) # 코너킥
H3_9 = (myform.get_text('i').split('i')[26])
A3_9 = (myform.get_text('i').split('i')[28]) # 프리킥
H3_10 = (myform.get_text('i').split('i')[29])
A3_10 = (myform.get_text('i').split('i')[31]) # 오프사이드
# 3라운드 #홈팀 성남 원정팀 서울 데이터

# %%
url_move(seoul_list[3])
btn = chrome.find_element(by='xpath', value='/html/body/div[2]/div/ul/li[2]')
btn.click()
time.sleep(1)
response_1 = chrome.page_source
number= BeautifulSoup(response_1).find('div', {'class':'formation'}).text.split()
# 왼쪽 홈팀 오른쪽 원정팀
Havg_4 = avg(number)[0]
Aavg_4 = avg(number)[1]
Havg_4
Aavg_4
response_1 = chrome.page_source
score= BeautifulSoup(response_1).find('div', {'class':'score campton'})
S4_1 = score.text[0:1]
S4_2 = score.text[2:3]
response_2 = chrome.page_source
myform = BeautifulSoup(response_2).find('div', {'class':'btn-cont'})
H4_1 = (myform.get_text('i').split('i')[1])
A4_1 = (myform.get_text('i').split('i')[3]) #점유율
H4_2 = (myform.get_text('i').split('i')[4])
A4_2 = (myform.get_text('i').split('i')[6]) #슈팅
H4_3 = (myform.get_text('i').split('i')[7])
A4_3 = (myform.get_text('i').split('i')[9]) # 유효슈팅
H4_4 = (myform.get_text('i').split('i')[10])
A4_4 = (myform.get_text('i').split('i')[12]) # 파울
H4_5 = (myform.get_text('i').split('i')[13])
A4_5 = (myform.get_text('i').split('i')[15]) # 경고
H4_6 = (myform.get_text('i').split('i')[16])
A4_6 = (myform.get_text('i').split('i')[18]) # 퇴장
H4_7 = (myform.get_text('i').split('i')[19])
A4_7 = (myform.get_text('i').split('i')[22]) #퇴장(경고누적)
H4_8 = (myform.get_text('i').split('i')[23])
A4_8 = (myform.get_text('i').split('i')[25]) # 코너킥
H4_9 = (myform.get_text('i').split('i')[26])
A4_9 = (myform.get_text('i').split('i')[28]) # 프리킥
H4_10 = (myform.get_text('i').split('i')[29])
A4_10 = (myform.get_text('i').split('i')[31]) # 오프사이드
 # 4라운드  홈팀 김천 원정팀 서울 데이터

# %%
url_move(seoul_list[4])
btn = chrome.find_element(by='xpath', value='/html/body/div[2]/div/ul/li[2]')
btn.click()
time.sleep(1)
response_1 = chrome.page_source
number= BeautifulSoup(response_1).find('div', {'class':'formation'}).text.split()
# 왼쪽 홈팀 오른쪽 원정팀
Havg_5 = avg(number)[0]
Aavg_5 = avg(number)[1]
Havg_5
Aavg_5
response_1 = chrome.page_source
score= BeautifulSoup(response_1).find('div', {'class':'score campton'})
S5_1 = score.text[0:1]
S5_2 = score.text[2:3]
response_2 = chrome.page_source
myform = BeautifulSoup(response_2).find('div', {'class':'btn-cont'})
H5_1 = (myform.get_text('i').split('i')[1])
A5_1 = (myform.get_text('i').split('i')[3]) #점유율
H5_2 = (myform.get_text('i').split('i')[4])
A5_2 = (myform.get_text('i').split('i')[6]) #슈팅
H5_3 = (myform.get_text('i').split('i')[7])
A5_3 = (myform.get_text('i').split('i')[9]) # 유효슈팅
H5_4 = (myform.get_text('i').split('i')[10])
A5_4 = (myform.get_text('i').split('i')[12]) # 파울
H5_5 = (myform.get_text('i').split('i')[13])
A5_5 = (myform.get_text('i').split('i')[15]) # 경고
H5_6 = (myform.get_text('i').split('i')[16])
A5_6 = (myform.get_text('i').split('i')[18]) # 퇴장
H5_7 = (myform.get_text('i').split('i')[19])
A5_7 = (myform.get_text('i').split('i')[22]) #퇴장(경고누적)
H5_8 = (myform.get_text('i').split('i')[23])
A5_8 = (myform.get_text('i').split('i')[25]) # 코너킥
H5_9 = (myform.get_text('i').split('i')[26])
A5_9 = (myform.get_text('i').split('i')[28]) # 프리킥
H5_10 = (myform.get_text('i').split('i')[29])
A5_10 = (myform.get_text('i').split('i')[31]) # 오프사이드
 # 5라운드  #홈팀 울산 원정팀 서울 데이터

# %%
url_move(seoul_list[5])
btn = chrome.find_element(by='xpath', value='/html/body/div[2]/div/ul/li[2]')
btn.click()
time.sleep(1)
response_1 = chrome.page_source
number= BeautifulSoup(response_1).find('div', {'class':'formation'}).text.split()
# 왼쪽 홈팀 오른쪽 원정팀
Havg_6 = avg(number)[0]
Aavg_6 = avg(number)[1]
Havg_6
Aavg_6
response_1 = chrome.page_source
score= BeautifulSoup(response_1).find('div', {'class':'score campton'})
S6_1 = score.text[0:1]
S6_2 = score.text[2:3]
response_2 = chrome.page_source
myform = BeautifulSoup(response_2).find('div', {'class':'btn-cont'})
H6_1 = (myform.get_text('i').split('i')[1])
A6_1 = (myform.get_text('i').split('i')[3]) #점유율
H6_2 = (myform.get_text('i').split('i')[4])
A6_2 = (myform.get_text('i').split('i')[6]) #슈팅
H6_3 = (myform.get_text('i').split('i')[7])
A6_3 = (myform.get_text('i').split('i')[9]) # 유효슈팅
H6_4 = (myform.get_text('i').split('i')[10])
A6_4 = (myform.get_text('i').split('i')[12]) # 파울
H6_5 = (myform.get_text('i').split('i')[13])
A6_5 = (myform.get_text('i').split('i')[15]) # 경고
H6_6 = (myform.get_text('i').split('i')[16])
A6_6 = (myform.get_text('i').split('i')[18]) # 퇴장
H6_7 = (myform.get_text('i').split('i')[19])
A6_7 = (myform.get_text('i').split('i')[22]) #퇴장(경고누적)
H6_8 = (myform.get_text('i').split('i')[23])
A6_8 = (myform.get_text('i').split('i')[25]) # 코너킥
H6_9 = (myform.get_text('i').split('i')[26])
A6_9 = (myform.get_text('i').split('i')[28]) # 프리킥
H6_10 = (myform.get_text('i').split('i')[29])
A6_10 = (myform.get_text('i').split('i')[31]) # 오프사이드
 # 6라운드 홈팀 서울 원정팀 제주 데이터

# %%
url_move(seoul_list[6])
btn = chrome.find_element(by='xpath', value='/html/body/div[2]/div/ul/li[2]')
btn.click()
time.sleep(1)
response_1 = chrome.page_source
number= BeautifulSoup(response_1).find('div', {'class':'formation'}).text.split()
# 왼쪽 홈팀 오른쪽 원정팀
Havg_7 = avg(number)[0]
Aavg_7 = avg(number)[1]
Havg_7
Aavg_7
response_1 = chrome.page_source
score= BeautifulSoup(response_1).find('div', {'class':'score campton'})
S7_1 = score.text[0:1]
S7_2 = score.text[2:3]
response_2 = chrome.page_source
myform = BeautifulSoup(response_2).find('div', {'class':'btn-cont'})
H7_1 = (myform.get_text('i').split('i')[1])
A7_1 = (myform.get_text('i').split('i')[3]) #점유율
H7_2 = (myform.get_text('i').split('i')[4])
A7_2 = (myform.get_text('i').split('i')[6]) #슈팅
H7_3 = (myform.get_text('i').split('i')[7])
A7_3 = (myform.get_text('i').split('i')[9]) # 유효슈팅
H7_4 = (myform.get_text('i').split('i')[10])
A7_4 = (myform.get_text('i').split('i')[12]) # 파울
H7_5 = (myform.get_text('i').split('i')[13])
A7_5 = (myform.get_text('i').split('i')[15]) # 경고
H7_6 = (myform.get_text('i').split('i')[16])
A7_6 = (myform.get_text('i').split('i')[18]) # 퇴장
H7_7 = (myform.get_text('i').split('i')[19])
A7_7 = (myform.get_text('i').split('i')[22]) #퇴장(경고누적)
H7_8 = (myform.get_text('i').split('i')[23])
A7_8 = (myform.get_text('i').split('i')[25]) # 코너킥
H7_9 = (myform.get_text('i').split('i')[26])
A7_9 = (myform.get_text('i').split('i')[28]) # 프리킥
H7_10 = (myform.get_text('i').split('i')[29])
A7_10 = (myform.get_text('i').split('i')[31]) # 오프사이드
 # 7라운드  홈팀 포항 원정팀 서울 데이터

# %%
url_move(seoul_list[7])
btn = chrome.find_element(by='xpath', value='/html/body/div[2]/div/ul/li[2]')
btn.click()
time.sleep(1)
response_1 = chrome.page_source
number= BeautifulSoup(response_1).find('div', {'class':'formation'}).text.split()
# 왼쪽 홈팀 오른쪽 원정팀
Havg_8 = avg(number)[0]
Aavg_8 = avg(number)[1]
Havg_8
Aavg_8
response_1 = chrome.page_source
score= BeautifulSoup(response_1).find('div', {'class':'score campton'})
S8_1 = score.text[0:1]
S8_2 = score.text[2:3]
response_2 = chrome.page_source
myform = BeautifulSoup(response_2).find('div', {'class':'btn-cont'})
H8_1 = (myform.get_text('i').split('i')[1])
A8_1 = (myform.get_text('i').split('i')[3]) #점유율
H8_2 = (myform.get_text('i').split('i')[4])
A8_2 = (myform.get_text('i').split('i')[6]) #슈팅
H8_3 = (myform.get_text('i').split('i')[7])
A8_3 = (myform.get_text('i').split('i')[9]) # 유효슈팅
H8_4 = (myform.get_text('i').split('i')[10])
A8_4 = (myform.get_text('i').split('i')[12]) # 파울
H8_5 = (myform.get_text('i').split('i')[13])
A8_5 = (myform.get_text('i').split('i')[15]) # 경고
H8_6 = (myform.get_text('i').split('i')[16])
A8_6 = (myform.get_text('i').split('i')[18]) # 퇴장
H8_7 = (myform.get_text('i').split('i')[19])
A8_7 = (myform.get_text('i').split('i')[22]) #퇴장(경고누적)
H8_8 = (myform.get_text('i').split('i')[23])
A8_8 = (myform.get_text('i').split('i')[25]) # 코너킥
H8_9 = (myform.get_text('i').split('i')[26])
A8_9 = (myform.get_text('i').split('i')[28]) # 프리킥
H8_10 = (myform.get_text('i').split('i')[29])
A8_10 = (myform.get_text('i').split('i')[31]) # 오프사이드
# 8라운드 홈팀 서울 원정팀 강원 데이터

# %%
url_move(seoul_list[8])
btn = chrome.find_element(by='xpath', value='/html/body/div[2]/div/ul/li[2]')
btn.click()
time.sleep(1)
response_1 = chrome.page_source
number= BeautifulSoup(response_1).find('div', {'class':'formation'}).text.split()
# 왼쪽 홈팀 오른쪽 원정팀
Havg_9 = avg(number)[0]
Aavg_9 = avg(number)[1]
Havg_9
Aavg_9
response_1 = chrome.page_source
score= BeautifulSoup(response_1).find('div', {'class':'score campton'})
S9_1 = score.text[0:1]
S9_2 = score.text[2:3]
response_2 = chrome.page_source
myform = BeautifulSoup(response_2).find('div', {'class':'btn-cont'})
H9_1 = (myform.get_text('i').split('i')[1])
A9_1 = (myform.get_text('i').split('i')[3]) #점유율
H9_2 = (myform.get_text('i').split('i')[4])
A9_2 = (myform.get_text('i').split('i')[6]) #슈팅
H9_3 = (myform.get_text('i').split('i')[7])
A9_3 = (myform.get_text('i').split('i')[9]) # 유효슈팅
H9_4 = (myform.get_text('i').split('i')[10])
A9_4 = (myform.get_text('i').split('i')[12]) # 파울
H9_5 = (myform.get_text('i').split('i')[13])
A9_5 = (myform.get_text('i').split('i')[15]) # 경고
H9_6 = (myform.get_text('i').split('i')[16])
A9_6 = (myform.get_text('i').split('i')[18]) # 퇴장
H9_7 = (myform.get_text('i').split('i')[19])
A9_7 = (myform.get_text('i').split('i')[22]) #퇴장(경고누적)
H9_8 = (myform.get_text('i').split('i')[23])
A9_8 = (myform.get_text('i').split('i')[25]) # 코너킥
H9_9 = (myform.get_text('i').split('i')[26])
A9_9 = (myform.get_text('i').split('i')[28]) # 프리킥
H9_10 = (myform.get_text('i').split('i')[29])
A9_10 = (myform.get_text('i').split('i')[31]) # 오프사이드
 # 9라운드  홈팀 서울 원정팀 수원 데이터

# %%
url_move(seoul_list[9])
btn = chrome.find_element(by='xpath', value='/html/body/div[2]/div/ul/li[2]')
btn.click()
time.sleep(1)
response_1 = chrome.page_source
number= BeautifulSoup(response_1).find('div', {'class':'formation'}).text.split()
# 왼쪽 홈팀 오른쪽 원정팀
Havg_10 = avg(number)[0]
Aavg_10 = avg(number)[1]
Havg_10
Aavg_10
response_1 = chrome.page_source
score= BeautifulSoup(response_1).find('div', {'class':'score campton'})
S10_1 = score.text[0:1]
S10_2 = score.text[2:3]
response_2 = chrome.page_source
myform = BeautifulSoup(response_2).find('div', {'class':'btn-cont'})
H10_1 = (myform.get_text('i').split('i')[1])
A10_1 = (myform.get_text('i').split('i')[3]) #점유율
H10_2 = (myform.get_text('i').split('i')[4])
A10_2 = (myform.get_text('i').split('i')[6]) #슈팅
H10_3 = (myform.get_text('i').split('i')[7])
A10_3 = (myform.get_text('i').split('i')[9]) # 유효슈팅
H10_4 = (myform.get_text('i').split('i')[10])
A10_4 = (myform.get_text('i').split('i')[12]) # 파울
H10_5 = (myform.get_text('i').split('i')[13])
A10_5 = (myform.get_text('i').split('i')[15]) # 경고
H10_6 = (myform.get_text('i').split('i')[16])
A10_6 = (myform.get_text('i').split('i')[18]) # 퇴장
H10_7 = (myform.get_text('i').split('i')[19])
A10_7 = (myform.get_text('i').split('i')[22]) #퇴장(경고누적)
H10_8 = (myform.get_text('i').split('i')[23])
A10_8 = (myform.get_text('i').split('i')[25]) # 코너킥
H10_9 = (myform.get_text('i').split('i')[26])
A10_9 = (myform.get_text('i').split('i')[28]) # 프리킥
H10_10 = (myform.get_text('i').split('i')[29])
A10_10 = (myform.get_text('i').split('i')[31]) # 오프사이드
 # 10라운드 홈팀 전북 원정팀 서울 데이터

# %%
url_move(seoul_list[10])
btn = chrome.find_element(by='xpath', value='/html/body/div[2]/div/ul/li[2]')
btn.click()
time.sleep(1)
response_1 = chrome.page_source
number= BeautifulSoup(response_1).find('div', {'class':'formation'}).text.split()
# 왼쪽 홈팀 오른쪽 원정팀
Havg_11 = avg(number)[0]
Aavg_11 = avg(number)[1]
Havg_11
Aavg_11
response_1 = chrome.page_source
score= BeautifulSoup(response_1).find('div', {'class':'score campton'})
S11_1 = score.text[0:1]
S11_2 = score.text[2:3]
response_2 = chrome.page_source
myform = BeautifulSoup(response_2).find('div', {'class':'btn-cont'})
H11_1 = (myform.get_text('i').split('i')[1])
A11_1 = (myform.get_text('i').split('i')[3]) #점유율
H11_2 = (myform.get_text('i').split('i')[4])
A11_2 = (myform.get_text('i').split('i')[6]) #슈팅
H11_3 = (myform.get_text('i').split('i')[7])
A11_3 = (myform.get_text('i').split('i')[9]) # 유효슈팅
H11_4 = (myform.get_text('i').split('i')[10])
A11_4 = (myform.get_text('i').split('i')[12]) # 파울
H11_5 = (myform.get_text('i').split('i')[13])
A11_5 = (myform.get_text('i').split('i')[15]) # 경고
H11_6 = (myform.get_text('i').split('i')[16])
A11_6 = (myform.get_text('i').split('i')[18]) # 퇴장
H11_7 = (myform.get_text('i').split('i')[19])
A11_7 = (myform.get_text('i').split('i')[22]) #퇴장(경고누적)
H11_8 = (myform.get_text('i').split('i')[23])
A11_8 = (myform.get_text('i').split('i')[25]) # 코너킥
H11_9 = (myform.get_text('i').split('i')[26])
A11_9 = (myform.get_text('i').split('i')[28]) # 프리킥
H11_10 = (myform.get_text('i').split('i')[29])
A11_10 = (myform.get_text('i').split('i')[31]) # 오프사이드
 # 11라운드 홈팀 서울 원정팀 수원FC 데이터

# %%
url_move(seoul_list[11])
btn = chrome.find_element(by='xpath', value='/html/body/div[2]/div/ul/li[2]')
btn.click()
time.sleep(1)
response_1 = chrome.page_source
number= BeautifulSoup(response_1).find('div', {'class':'formation'}).text.split()
# 왼쪽 홈팀 오른쪽 원정팀
Havg_12 = avg(number)[0]
Aavg_12 = avg(number)[1]
Havg_12
Aavg_12
response_1 = chrome.page_source
score= BeautifulSoup(response_1).find('div', {'class':'score campton'})
S12_1 = score.text[0:1]
S12_2 = score.text[2:3]
response_2 = chrome.page_source
myform = BeautifulSoup(response_2).find('div', {'class':'btn-cont'})
H12_1 = (myform.get_text('i').split('i')[1])
A12_1 = (myform.get_text('i').split('i')[3]) #점유율
H12_2 = (myform.get_text('i').split('i')[4])
A12_2 = (myform.get_text('i').split('i')[6]) #슈팅
H12_3 = (myform.get_text('i').split('i')[7])
A12_3 = (myform.get_text('i').split('i')[9]) # 유효슈팅
H12_4 = (myform.get_text('i').split('i')[10])
A12_4 = (myform.get_text('i').split('i')[12]) # 파울
H12_5 = (myform.get_text('i').split('i')[13])
A12_5 = (myform.get_text('i').split('i')[15]) # 경고
H12_6 = (myform.get_text('i').split('i')[16])
A12_6 = (myform.get_text('i').split('i')[18]) # 퇴장
H12_7 = (myform.get_text('i').split('i')[19])
A12_7 = (myform.get_text('i').split('i')[22]) #퇴장(경고누적)
H12_8 = (myform.get_text('i').split('i')[23])
A12_8 = (myform.get_text('i').split('i')[25]) # 코너킥
H12_9 = (myform.get_text('i').split('i')[26])
A12_9 = (myform.get_text('i').split('i')[28]) # 프리킥
H12_10 = (myform.get_text('i').split('i')[29])
A12_10 = (myform.get_text('i').split('i')[31]) # 오프사이드
 # 12라운드 홈팀 서울 원정팀 포항 데이터

# %%
url_move(seoul_list[12])
btn = chrome.find_element(by='xpath', value='/html/body/div[2]/div/ul/li[2]')
btn.click()
time.sleep(1)
response_1 = chrome.page_source
number= BeautifulSoup(response_1).find('div', {'class':'formation'}).text.split()
# 왼쪽 홈팀 오른쪽 원정팀
Havg_13 = avg(number)[0]
Aavg_13 = avg(number)[1]
Havg_13
Aavg_13
response_1 = chrome.page_source
score= BeautifulSoup(response_1).find('div', {'class':'score campton'})
S13_1 = score.text[0:1]
S13_2 = score.text[2:3]
response_2 = chrome.page_source
myform = BeautifulSoup(response_2).find('div', {'class':'btn-cont'})
H13_1 = (myform.get_text('i').split('i')[1])
A13_1 = (myform.get_text('i').split('i')[3]) #점유율
H13_2 = (myform.get_text('i').split('i')[4])
A13_2 = (myform.get_text('i').split('i')[6]) #슈팅
H13_3 = (myform.get_text('i').split('i')[7])
A13_3 = (myform.get_text('i').split('i')[9]) # 유효슈팅
H13_4 = (myform.get_text('i').split('i')[10])
A13_4 = (myform.get_text('i').split('i')[12]) # 파울
H13_5 = (myform.get_text('i').split('i')[13])
A13_5 = (myform.get_text('i').split('i')[15]) # 경고
H13_6 = (myform.get_text('i').split('i')[16])
A13_6 = (myform.get_text('i').split('i')[18]) # 퇴장
H13_7 = (myform.get_text('i').split('i')[19])
A13_7 = (myform.get_text('i').split('i')[22]) #퇴장(경고누적)
H13_8 = (myform.get_text('i').split('i')[23])
A13_8 = (myform.get_text('i').split('i')[25]) # 코너킥
H13_9 = (myform.get_text('i').split('i')[26])
A13_9 = (myform.get_text('i').split('i')[28]) # 프리킥
H13_10 = (myform.get_text('i').split('i')[29])
A13_10 = (myform.get_text('i').split('i')[31]) # 오프사이드
 # 13라운드 홈팀 강원 원정팀 서울 데이터

# %%
url_move(seoul_list[13])
btn = chrome.find_element(by='xpath', value='/html/body/div[2]/div/ul/li[2]')
btn.click()
time.sleep(1)
response_1 = chrome.page_source
number= BeautifulSoup(response_1).find('div', {'class':'formation'}).text.split()
# 왼쪽 홈팀 오른쪽 원정팀
Havg_14 = avg(number)[0]
Aavg_14 = avg(number)[1]
Havg_14
Aavg_14
response_1 = chrome.page_source
score= BeautifulSoup(response_1).find('div', {'class':'score campton'})
S14_1 = score.text[0:1]
S14_2 = score.text[2:3]
response_2 = chrome.page_source
myform = BeautifulSoup(response_2).find('div', {'class':'btn-cont'})
H14_1 = (myform.get_text('i').split('i')[1])
A14_1 = (myform.get_text('i').split('i')[3]) #점유율
H14_2 = (myform.get_text('i').split('i')[4])
A14_2 = (myform.get_text('i').split('i')[6]) #슈팅
H14_3 = (myform.get_text('i').split('i')[7])
A14_3 = (myform.get_text('i').split('i')[9]) # 유효슈팅
H14_4 = (myform.get_text('i').split('i')[10])
A14_4 = (myform.get_text('i').split('i')[12]) # 파울
H14_5 = (myform.get_text('i').split('i')[13])
A14_5 = (myform.get_text('i').split('i')[15]) # 경고
H14_6 = (myform.get_text('i').split('i')[16])
A14_6 = (myform.get_text('i').split('i')[18]) # 퇴장
H14_7 = (myform.get_text('i').split('i')[19])
A14_7 = (myform.get_text('i').split('i')[22]) #퇴장(경고누적)
H14_8 = (myform.get_text('i').split('i')[23])
A14_8 = (myform.get_text('i').split('i')[25]) # 코너킥
H14_9 = (myform.get_text('i').split('i')[26])
A14_9 = (myform.get_text('i').split('i')[28]) # 프리킥
H14_10 = (myform.get_text('i').split('i')[29])
A14_10 = (myform.get_text('i').split('i')[31]) # 오프사이드
 # 14라운드 홈팀 서울 원정팀 성남 데이터

# %%
url_move(seoul_list[14])
btn = chrome.find_element(by='xpath', value='/html/body/div[2]/div/ul/li[2]')
btn.click()
time.sleep(1)
response_1 = chrome.page_source
number= BeautifulSoup(response_1).find('div', {'class':'formation'}).text.split()
# 왼쪽 홈팀 오른쪽 원정팀
Havg_15 = avg(number)[0]
Aavg_15 = avg(number)[1]
Havg_15
Aavg_15
response_1 = chrome.page_source
score= BeautifulSoup(response_1).find('div', {'class':'score campton'})
S15_1 = score.text[0:1]
S15_2 = score.text[2:3]
response_2 = chrome.page_source
myform = BeautifulSoup(response_2).find('div', {'class':'btn-cont'})
H15_1 = (myform.get_text('i').split('i')[1])
A15_1 = (myform.get_text('i').split('i')[3]) #점유율
H15_2 = (myform.get_text('i').split('i')[4])
A15_2 = (myform.get_text('i').split('i')[6]) #슈팅
H15_3 = (myform.get_text('i').split('i')[7])
A15_3 = (myform.get_text('i').split('i')[9]) # 유효슈팅
H15_4 = (myform.get_text('i').split('i')[10])
A15_4 = (myform.get_text('i').split('i')[12]) # 파울
H15_5 = (myform.get_text('i').split('i')[13])
A15_5 = (myform.get_text('i').split('i')[15]) # 경고
H15_6 = (myform.get_text('i').split('i')[16])
A15_6 = (myform.get_text('i').split('i')[18]) # 퇴장
H15_7 = (myform.get_text('i').split('i')[19])
A15_7 = (myform.get_text('i').split('i')[22]) #퇴장(경고누적)
H15_8 = (myform.get_text('i').split('i')[23])
A15_8 = (myform.get_text('i').split('i')[25]) # 코너킥
H15_9 = (myform.get_text('i').split('i')[26])
A15_9 = (myform.get_text('i').split('i')[28]) # 프리킥
H15_10 = (myform.get_text('i').split('i')[29])
A15_10 = (myform.get_text('i').split('i')[31]) # 오프사이드
 # 15라운드 홈팀 서울 원정팀 김천 데이터

# %%
url_move(seoul_list[15])
btn = chrome.find_element(by='xpath', value='/html/body/div[2]/div/ul/li[2]')
btn.click()
time.sleep(1)
response_1 = chrome.page_source
number= BeautifulSoup(response_1).find('div', {'class':'formation'}).text.split()
# 왼쪽 홈팀 오른쪽 원정팀
Havg_16 = avg(number)[0]
Aavg_16 = avg(number)[1]
Havg_16
Aavg_16
response_1 = chrome.page_source
score= BeautifulSoup(response_1).find('div', {'class':'score campton'})
S16_1 = score.text[0:1]
S16_2 = score.text[2:3]
response_2 = chrome.page_source
myform = BeautifulSoup(response_2).find('div', {'class':'btn-cont'})
H16_1 = (myform.get_text('i').split('i')[1])
A16_1 = (myform.get_text('i').split('i')[3]) #점유율
H16_2 = (myform.get_text('i').split('i')[4])
A16_2 = (myform.get_text('i').split('i')[6]) #슈팅
H16_3 = (myform.get_text('i').split('i')[7])
A16_3 = (myform.get_text('i').split('i')[9]) # 유효슈팅
H16_4 = (myform.get_text('i').split('i')[10])
A16_4 = (myform.get_text('i').split('i')[12]) # 파울
H16_5 = (myform.get_text('i').split('i')[13])
A16_5 = (myform.get_text('i').split('i')[15]) # 경고
H16_6 = (myform.get_text('i').split('i')[16])
A16_6 = (myform.get_text('i').split('i')[18]) # 퇴장
H16_7 = (myform.get_text('i').split('i')[19])
A16_7 = (myform.get_text('i').split('i')[22]) #퇴장(경고누적)
H16_8 = (myform.get_text('i').split('i')[23])
A16_8 = (myform.get_text('i').split('i')[25]) # 코너킥
H16_9 = (myform.get_text('i').split('i')[26])
A16_9 = (myform.get_text('i').split('i')[28]) # 프리킥
H16_10 = (myform.get_text('i').split('i')[29])
A16_10 = (myform.get_text('i').split('i')[31]) # 오프사이드
 # 16라운드 홈팀 수원 원정팀 서울 데이터

# %%
url_move(seoul_list[16])
btn = chrome.find_element(by='xpath', value='/html/body/div[2]/div/ul/li[2]')
btn.click()
time.sleep(1)
response_1 = chrome.page_source
number= BeautifulSoup(response_1).find('div', {'class':'formation'}).text.split()
# 왼쪽 홈팀 오른쪽 원정팀
Havg_17 = avg(number)[0]
Aavg_17 = avg(number)[1]
Havg_17
Aavg_17
response_1 = chrome.page_source
score= BeautifulSoup(response_1).find('div', {'class':'score campton'})
S17_1 = score.text[0:1]
S17_2 = score.text[2:3]
response_2 = chrome.page_source
myform = BeautifulSoup(response_2).find('div', {'class':'btn-cont'})
H17_1 = (myform.get_text('i').split('i')[1])
A17_1 = (myform.get_text('i').split('i')[3]) #점유율
H17_2 = (myform.get_text('i').split('i')[4])
A17_2 = (myform.get_text('i').split('i')[6]) #슈팅
H17_3 = (myform.get_text('i').split('i')[7])
A17_3 = (myform.get_text('i').split('i')[9]) # 유효슈팅
H17_4 = (myform.get_text('i').split('i')[10])
A17_4 = (myform.get_text('i').split('i')[12]) # 파울
H17_5 = (myform.get_text('i').split('i')[13])
A17_5 = (myform.get_text('i').split('i')[15]) # 경고
H17_6 = (myform.get_text('i').split('i')[16])
A17_6 = (myform.get_text('i').split('i')[18]) # 퇴장
H17_7 = (myform.get_text('i').split('i')[19])
A17_7 = (myform.get_text('i').split('i')[22]) #퇴장(경고누적)
H17_8 = (myform.get_text('i').split('i')[23])
A17_8 = (myform.get_text('i').split('i')[25]) # 코너킥
H17_9 = (myform.get_text('i').split('i')[26])
A17_9 = (myform.get_text('i').split('i')[28]) # 프리킥
H17_10 = (myform.get_text('i').split('i')[29])
A17_10 = (myform.get_text('i').split('i')[31]) # 오프사이드
 # 17라운드 홈팀 서울 원정팀 울산 데이터

# %%
url_move(seoul_list[17])
btn = chrome.find_element(by='xpath', value='/html/body/div[2]/div/ul/li[2]')
btn.click()
time.sleep(1)
response_1 = chrome.page_source
number= BeautifulSoup(response_1).find('div', {'class':'formation'}).text.split()
# 왼쪽 홈팀 오른쪽 원정팀
Havg_18 = avg(number)[0]
Aavg_18 = avg(number)[1]
Havg_18
Aavg_18
response_1 = chrome.page_source
score= BeautifulSoup(response_1).find('div', {'class':'score campton'})
S18_1 = score.text[0:1]
S18_2 = score.text[2:3]
response_2 = chrome.page_source
myform = BeautifulSoup(response_2).find('div', {'class':'btn-cont'})
H18_1 = (myform.get_text('i').split('i')[1])
A18_1 = (myform.get_text('i').split('i')[3]) #점유율
H18_2 = (myform.get_text('i').split('i')[4])
A18_2 = (myform.get_text('i').split('i')[6]) #슈팅
H18_3 = (myform.get_text('i').split('i')[7])
A18_3 = (myform.get_text('i').split('i')[9]) # 유효슈팅
H18_4 = (myform.get_text('i').split('i')[10])
A18_4 = (myform.get_text('i').split('i')[12]) # 파울
H18_5 = (myform.get_text('i').split('i')[13])
A18_5 = (myform.get_text('i').split('i')[15]) # 경고
H18_6 = (myform.get_text('i').split('i')[16])
A18_6 = (myform.get_text('i').split('i')[18]) # 퇴장
H18_7 = (myform.get_text('i').split('i')[19])
A18_7 = (myform.get_text('i').split('i')[22]) #퇴장(경고누적)
H18_8 = (myform.get_text('i').split('i')[23])
A18_8 = (myform.get_text('i').split('i')[25]) # 코너킥
H18_9 = (myform.get_text('i').split('i')[26])
A18_9 = (myform.get_text('i').split('i')[28]) # 프리킥
H18_10 = (myform.get_text('i').split('i')[29])
A18_10 = (myform.get_text('i').split('i')[31]) # 오프사이드
 # 18라운드 홈팀 서울 원정팀 인천 데이터

# %%
url_move(seoul_list[18])
btn = chrome.find_element(by='xpath', value='/html/body/div[2]/div/ul/li[2]')
btn.click()
time.sleep(1)
response_1 = chrome.page_source
number= BeautifulSoup(response_1).find('div', {'class':'formation'}).text.split()
# 왼쪽 홈팀 오른쪽 원정팀
Havg_19 = avg(number)[0]
Aavg_19 = avg(number)[1]
Havg_19
Aavg_19
response_1 = chrome.page_source
score= BeautifulSoup(response_1).find('div', {'class':'score campton'})
S19_1 = score.text[0:1]
S19_2 = score.text[2:3]
response_2 = chrome.page_source
myform = BeautifulSoup(response_2).find('div', {'class':'btn-cont'})
H19_1 = (myform.get_text('i').split('i')[1])
A19_1 = (myform.get_text('i').split('i')[3]) #점유율
H19_2 = (myform.get_text('i').split('i')[4])
A19_2 = (myform.get_text('i').split('i')[6]) #슈팅
H19_3 = (myform.get_text('i').split('i')[7])
A19_3 = (myform.get_text('i').split('i')[9]) # 유효슈팅
H19_4 = (myform.get_text('i').split('i')[10])
A19_4 = (myform.get_text('i').split('i')[12]) # 파울
H19_5 = (myform.get_text('i').split('i')[13])
A19_5 = (myform.get_text('i').split('i')[15]) # 경고
H19_6 = (myform.get_text('i').split('i')[16])
A19_6 = (myform.get_text('i').split('i')[18]) # 퇴장
H19_7 = (myform.get_text('i').split('i')[19])
A19_7 = (myform.get_text('i').split('i')[22]) #퇴장(경고누적)
H19_8 = (myform.get_text('i').split('i')[23])
A19_8 = (myform.get_text('i').split('i')[25]) # 코너킥
H19_9 = (myform.get_text('i').split('i')[26])
A19_9 = (myform.get_text('i').split('i')[28]) # 프리킥
H19_10 = (myform.get_text('i').split('i')[29])
A19_10 = (myform.get_text('i').split('i')[31]) # 오프사이드
 # 19라운드 홈팀 제주 원정팀 서울  데이터

# %%
url_move(seoul_list[19])
btn = chrome.find_element(by='xpath', value='/html/body/div[2]/div/ul/li[2]')
btn.click()
time.sleep(1)
response_1 = chrome.page_source
number= BeautifulSoup(response_1).find('div', {'class':'formation'}).text.split()
# 왼쪽 홈팀 오른쪽 원정팀
Havg_20 = avg(number)[0]
Aavg_20 = avg(number)[1]
Havg_20
Aavg_20
response_1 = chrome.page_source
score= BeautifulSoup(response_1).find('div', {'class':'score campton'})
S20_1 = score.text[0:1]
S20_2 = score.text[2:3]
response_2 = chrome.page_source
myform = BeautifulSoup(response_2).find('div', {'class':'btn-cont'})
H20_1 = (myform.get_text('i').split('i')[1])
A20_1 = (myform.get_text('i').split('i')[3]) #점유율
H20_2 = (myform.get_text('i').split('i')[4])
A20_2 = (myform.get_text('i').split('i')[6]) #슈팅
H20_3 = (myform.get_text('i').split('i')[7])
A20_3 = (myform.get_text('i').split('i')[9]) # 유효슈팅
H20_4 = (myform.get_text('i').split('i')[10])
A20_4 = (myform.get_text('i').split('i')[12]) # 파울
H20_5 = (myform.get_text('i').split('i')[13])
A20_5 = (myform.get_text('i').split('i')[15]) # 경고
H20_6 = (myform.get_text('i').split('i')[16])
A20_6 = (myform.get_text('i').split('i')[18]) # 퇴장
H20_7 = (myform.get_text('i').split('i')[19])
A20_7 = (myform.get_text('i').split('i')[22]) #퇴장(경고누적)
H20_8 = (myform.get_text('i').split('i')[23])
A20_8 = (myform.get_text('i').split('i')[25]) # 코너킥
H20_9 = (myform.get_text('i').split('i')[26])
A20_9 = (myform.get_text('i').split('i')[28]) # 프리킥
H20_10 = (myform.get_text('i').split('i')[29])
A20_10 = (myform.get_text('i').split('i')[31]) # 오프사이드
# 20라운드 홈팀 서울 원정팀 전북 데이터

# %%
url_move(seoul_list[20])
btn = chrome.find_element(by='xpath', value='/html/body/div[2]/div/ul/li[2]')
btn.click()
time.sleep(1)
response_1 = chrome.page_source
number= BeautifulSoup(response_1).find('div', {'class':'formation'}).text.split()
# 왼쪽 홈팀 오른쪽 원정팀
Havg_21 = avg(number)[0]
Aavg_21 = avg(number)[1]
Havg_21
Aavg_21
response_1 = chrome.page_source
score= BeautifulSoup(response_1).find('div', {'class':'score campton'})
S21_1 = score.text[0:1]
S21_2 = score.text[2:3]
response_2 = chrome.page_source
myform = BeautifulSoup(response_2).find('div', {'class':'btn-cont'})
H21_1 = (myform.get_text('i').split('i')[1])
A21_1 = (myform.get_text('i').split('i')[3]) #점유율
H21_2 = (myform.get_text('i').split('i')[4])
A21_2 = (myform.get_text('i').split('i')[6]) #슈팅
H21_3 = (myform.get_text('i').split('i')[7])
A21_3 = (myform.get_text('i').split('i')[9]) # 유효슈팅
H21_4 = (myform.get_text('i').split('i')[10])
A21_4 = (myform.get_text('i').split('i')[12]) # 파울
H21_5 = (myform.get_text('i').split('i')[13])
A21_5 = (myform.get_text('i').split('i')[15]) # 경고
H21_6 = (myform.get_text('i').split('i')[16])
A21_6 = (myform.get_text('i').split('i')[18]) # 퇴장
H21_7 = (myform.get_text('i').split('i')[19])
A21_7 = (myform.get_text('i').split('i')[22]) #퇴장(경고누적)
H21_8 = (myform.get_text('i').split('i')[23])
A21_8 = (myform.get_text('i').split('i')[25]) # 코너킥
H21_9 = (myform.get_text('i').split('i')[26])
A21_9 = (myform.get_text('i').split('i')[28]) # 프리킥
H21_10 = (myform.get_text('i').split('i')[29])
A21_10 = (myform.get_text('i').split('i')[31]) # 오프사이드
 # 21라운드 홈팀 수원FC 원정팀 서울 데이터

# %%
url_move(seoul_list[21])
btn = chrome.find_element(by='xpath', value='/html/body/div[2]/div/ul/li[2]')
btn.click()
time.sleep(1)
response_1 = chrome.page_source
number= BeautifulSoup(response_1).find('div', {'class':'formation'}).text.split()
# 왼쪽 홈팀 오른쪽 원정팀
Havg_22 = avg(number)[0]
Aavg_22 = avg(number)[1]
Havg_22
Aavg_22
response_1 = chrome.page_source
score= BeautifulSoup(response_1).find('div', {'class':'score campton'})
S22_1 = score.text[0:1]
S22_2 = score.text[2:3]
response_2 = chrome.page_source
myform = BeautifulSoup(response_2).find('div', {'class':'btn-cont'})
H22_1 = (myform.get_text('i').split('i')[1])
A22_1 = (myform.get_text('i').split('i')[3]) #점유율
H22_2 = (myform.get_text('i').split('i')[4])
A22_2 = (myform.get_text('i').split('i')[6]) #슈팅
H22_3 = (myform.get_text('i').split('i')[7])
A22_3 = (myform.get_text('i').split('i')[9]) # 유효슈팅
H22_4 = (myform.get_text('i').split('i')[10])
A22_4 = (myform.get_text('i').split('i')[12]) # 파울
H22_5 = (myform.get_text('i').split('i')[13])
A22_5 = (myform.get_text('i').split('i')[15]) # 경고
H22_6 = (myform.get_text('i').split('i')[16])
A22_6 = (myform.get_text('i').split('i')[18]) # 퇴장
H22_7 = (myform.get_text('i').split('i')[19])
A22_7 = (myform.get_text('i').split('i')[22]) #퇴장(경고누적)
H22_8 = (myform.get_text('i').split('i')[23])
A22_8 = (myform.get_text('i').split('i')[25]) # 코너킥
H22_9 = (myform.get_text('i').split('i')[26])
A22_9 = (myform.get_text('i').split('i')[28]) # 프리킥
H22_10 = (myform.get_text('i').split('i')[29])
A22_10 = (myform.get_text('i').split('i')[31]) # 오프사이드
 # 22라운드 팀 서울 원정팀 대구 데이터

# %%
url_move(seoul_list[22])
btn = chrome.find_element(by='xpath', value='/html/body/div[2]/div/ul/li[2]')
btn.click()
time.sleep(1)
response_1 = chrome.page_source
number= BeautifulSoup(response_1).find('div', {'class':'formation'}).text.split()
# 왼쪽 홈팀 오른쪽 원정팀
Havg_23 = avg(number)[0]
Aavg_23 = avg(number)[1]
Havg_23
Aavg_23
response_1 = chrome.page_source
score= BeautifulSoup(response_1).find('div', {'class':'score campton'})
S23_1 = score.text[0:1]
S23_2 = score.text[2:3]
response_2 = chrome.page_source
myform = BeautifulSoup(response_2).find('div', {'class':'btn-cont'})
H23_1 = (myform.get_text('i').split('i')[1])
A23_1 = (myform.get_text('i').split('i')[3]) #점유율
H23_2 = (myform.get_text('i').split('i')[4])
A23_2 = (myform.get_text('i').split('i')[6]) #슈팅
H23_3 = (myform.get_text('i').split('i')[7])
A23_3 = (myform.get_text('i').split('i')[9]) # 유효슈팅
H23_4 = (myform.get_text('i').split('i')[10])
A23_4 = (myform.get_text('i').split('i')[12]) # 파울
H23_5 = (myform.get_text('i').split('i')[13])
A23_5 = (myform.get_text('i').split('i')[15]) # 경고
H23_6 = (myform.get_text('i').split('i')[16])
A23_6 = (myform.get_text('i').split('i')[18]) # 퇴장
H23_7 = (myform.get_text('i').split('i')[19])
A23_7 = (myform.get_text('i').split('i')[22]) #퇴장(경고누적)
H23_8 = (myform.get_text('i').split('i')[23])
A23_8 = (myform.get_text('i').split('i')[25]) # 코너킥
H23_9 = (myform.get_text('i').split('i')[26])
A23_9 = (myform.get_text('i').split('i')[28]) # 프리킥
H23_10 = (myform.get_text('i').split('i')[29])
A23_10 = (myform.get_text('i').split('i')[31]) # 오프사이드
 # 25라운드 홈팀 포항 원정팀 서울 데이터

# %%
url_move(seoul_list[23])
btn = chrome.find_element(by='xpath', value='/html/body/div[2]/div/ul/li[2]')
btn.click()
time.sleep(1)
response_1 = chrome.page_source
number= BeautifulSoup(response_1).find('div', {'class':'formation'}).text.split()
# 왼쪽 홈팀 오른쪽 원정팀
Havg_24 = avg(number)[0]
Aavg_24 = avg(number)[1]
Havg_24
Aavg_24
response_1 = chrome.page_source
score= BeautifulSoup(response_1).find('div', {'class':'score campton'})
S24_1 = score.text[0:1]
S24_2 = score.text[2:3]
response_2 = chrome.page_source
myform = BeautifulSoup(response_2).find('div', {'class':'btn-cont'})
H24_1 = (myform.get_text('i').split('i')[1])
A24_1 = (myform.get_text('i').split('i')[3]) #점유율
H24_2 = (myform.get_text('i').split('i')[4])
A24_2 = (myform.get_text('i').split('i')[6]) #슈팅
H24_3 = (myform.get_text('i').split('i')[7])
A24_3 = (myform.get_text('i').split('i')[9]) # 유효슈팅
H24_4 = (myform.get_text('i').split('i')[10])
A24_4 = (myform.get_text('i').split('i')[12]) # 파울
H24_5 = (myform.get_text('i').split('i')[13])
A24_5 = (myform.get_text('i').split('i')[15]) # 경고
H24_6 = (myform.get_text('i').split('i')[16])
A24_6 = (myform.get_text('i').split('i')[18]) # 퇴장
H24_7 = (myform.get_text('i').split('i')[19])
A24_7 = (myform.get_text('i').split('i')[22]) #퇴장(경고누적)
H24_8 = (myform.get_text('i').split('i')[23])
A24_8 = (myform.get_text('i').split('i')[25]) # 코너킥
H24_9 = (myform.get_text('i').split('i')[26])
A24_9 = (myform.get_text('i').split('i')[28]) # 프리킥
H24_10 = (myform.get_text('i').split('i')[29])
A24_10 = (myform.get_text('i').split('i')[31]) # 오프사이드
 # 26라운드 홈팀 울산 원정팀 서울 데이터

# %%
url_move(seoul_list[24])
btn = chrome.find_element(by='xpath', value='/html/body/div[2]/div/ul/li[2]')
btn.click()
time.sleep(1)
response_1 = chrome.page_source
number= BeautifulSoup(response_1).find('div', {'class':'formation'}).text.split()
# 왼쪽 홈팀 오른쪽 원정팀
Havg_25 = avg(number)[0]
Aavg_25 = avg(number)[1]
Havg_25
Aavg_25
response_1 = chrome.page_source
score= BeautifulSoup(response_1).find('div', {'class':'score campton'})
S25_1 = score.text[0:1]
S25_2 = score.text[2:3]
response_2 = chrome.page_source
myform = BeautifulSoup(response_2).find('div', {'class':'btn-cont'})
H25_1 = (myform.get_text('i').split('i')[1])
A25_1 = (myform.get_text('i').split('i')[3]) #점유율
H25_2 = (myform.get_text('i').split('i')[4])
A25_2 = (myform.get_text('i').split('i')[6]) #슈팅
H25_3 = (myform.get_text('i').split('i')[7])
A25_3 = (myform.get_text('i').split('i')[9]) # 유효슈팅
H25_4 = (myform.get_text('i').split('i')[10])
A25_4 = (myform.get_text('i').split('i')[12]) # 파울
H25_5 = (myform.get_text('i').split('i')[13])
A25_5 = (myform.get_text('i').split('i')[15]) # 경고
H25_6 = (myform.get_text('i').split('i')[16])
A25_6 = (myform.get_text('i').split('i')[18]) # 퇴장
H25_7 = (myform.get_text('i').split('i')[19])
A25_7 = (myform.get_text('i').split('i')[22]) #퇴장(경고누적)
H25_8 = (myform.get_text('i').split('i')[23])
A25_8 = (myform.get_text('i').split('i')[25]) # 코너킥
H25_9 = (myform.get_text('i').split('i')[26])
A25_9 = (myform.get_text('i').split('i')[28]) # 프리킥
H25_10 = (myform.get_text('i').split('i')[29])
A25_10 = (myform.get_text('i').split('i')[31]) # 오프사이드
 # 27라운드 홈팀 서울 원정팀 제주 데이터

# %%
url_move(seoul_list[25])
btn = chrome.find_element(by='xpath', value='/html/body/div[2]/div/ul/li[2]')
btn.click()
time.sleep(1)
response_1 = chrome.page_source
number= BeautifulSoup(response_1).find('div', {'class':'formation'}).text.split()
# 왼쪽 홈팀 오른쪽 원정팀
Havg_26 = avg(number)[0]
Aavg_26 = avg(number)[1]
Havg_26
Aavg_26
response_1 = chrome.page_source
score= BeautifulSoup(response_1).find('div', {'class':'score campton'})
S26_1 = score.text[0:1]
S26_2 = score.text[2:3]
response_2 = chrome.page_source
myform = BeautifulSoup(response_2).find('div', {'class':'btn-cont'})
H26_1 = (myform.get_text('i').split('i')[1])
A26_1 = (myform.get_text('i').split('i')[3]) #점유율
H26_2 = (myform.get_text('i').split('i')[4])
A26_2 = (myform.get_text('i').split('i')[6]) #슈팅
H26_3 = (myform.get_text('i').split('i')[7])
A26_3 = (myform.get_text('i').split('i')[9]) # 유효슈팅
H26_4 = (myform.get_text('i').split('i')[10])
A26_4 = (myform.get_text('i').split('i')[12]) # 파울
H26_5 = (myform.get_text('i').split('i')[13])
A26_5 = (myform.get_text('i').split('i')[15]) # 경고
H26_6 = (myform.get_text('i').split('i')[16])
A26_6 = (myform.get_text('i').split('i')[18]) # 퇴장
H26_7 = (myform.get_text('i').split('i')[19])
A26_7 = (myform.get_text('i').split('i')[22]) #퇴장(경고누적)
H26_8 = (myform.get_text('i').split('i')[23])
A26_8 = (myform.get_text('i').split('i')[25]) # 코너킥
H26_9 = (myform.get_text('i').split('i')[26])
A26_9 = (myform.get_text('i').split('i')[28]) # 프리킥
H26_10 = (myform.get_text('i').split('i')[29])
A26_10 = (myform.get_text('i').split('i')[31]) # 오프사이드
 # 28라운드 홈팀 김천 원정팀 서울 데이터

# %%
url_move(seoul_list[26])
btn = chrome.find_element(by='xpath', value='/html/body/div[2]/div/ul/li[2]')
btn.click()
time.sleep(1)
response_1 = chrome.page_source
number= BeautifulSoup(response_1).find('div', {'class':'formation'}).text.split()
# 왼쪽 홈팀 오른쪽 원정팀
Havg_27 = avg(number)[0]
Aavg_27 = avg(number)[1]
Havg_27
Aavg_27
response_1 = chrome.page_source
score= BeautifulSoup(response_1).find('div', {'class':'score campton'})
S27_1 = score.text[0:1]
S27_2 = score.text[2:3]
response_2 = chrome.page_source
myform = BeautifulSoup(response_2).find('div', {'class':'btn-cont'})
H27_1 = (myform.get_text('i').split('i')[1])
A27_1 = (myform.get_text('i').split('i')[3]) #점유율
H27_2 = (myform.get_text('i').split('i')[4])
A27_2 = (myform.get_text('i').split('i')[6]) #슈팅
H27_3 = (myform.get_text('i').split('i')[7])
A27_3 = (myform.get_text('i').split('i')[9]) # 유효슈팅
H27_4 = (myform.get_text('i').split('i')[10])
A27_4 = (myform.get_text('i').split('i')[12]) # 파울
H27_5 = (myform.get_text('i').split('i')[13])
A27_5 = (myform.get_text('i').split('i')[15]) # 경고
H27_6 = (myform.get_text('i').split('i')[16])
A27_6 = (myform.get_text('i').split('i')[18]) # 퇴장
H27_7 = (myform.get_text('i').split('i')[19])
A27_7 = (myform.get_text('i').split('i')[22]) #퇴장(경고누적)
H27_8 = (myform.get_text('i').split('i')[23])
A27_8 = (myform.get_text('i').split('i')[25]) # 코너킥
H27_9 = (myform.get_text('i').split('i')[26])
A27_9 = (myform.get_text('i').split('i')[28]) # 프리킥
H27_10 = (myform.get_text('i').split('i')[29])
A27_10 = (myform.get_text('i').split('i')[31]) # 오프사이드
 # 24라운드 홈팀 서울 원정팀 성남 데이터

# %%
url_move(seoul_list[27])
btn = chrome.find_element(by='xpath', value='/html/body/div[2]/div/ul/li[2]')
btn.click()
time.sleep(1)
response_1 = chrome.page_source
number= BeautifulSoup(response_1).find('div', {'class':'formation'}).text.split()
# 왼쪽 홈팀 오른쪽 원정팀
Havg_28 = avg(number)[0]
Aavg_28 = avg(number)[1]
Havg_28
Aavg_28
response_1 = chrome.page_source
score= BeautifulSoup(response_1).find('div', {'class':'score campton'})
S28_1 = score.text[0:1]
S28_2 = score.text[2:3]
response_2 = chrome.page_source
myform = BeautifulSoup(response_2).find('div', {'class':'btn-cont'})
H28_1 = (myform.get_text('i').split('i')[1])
A28_1 = (myform.get_text('i').split('i')[3]) #점유율
H28_2 = (myform.get_text('i').split('i')[4])
A28_2 = (myform.get_text('i').split('i')[6]) #슈팅
H28_3 = (myform.get_text('i').split('i')[7])
A28_3 = (myform.get_text('i').split('i')[9]) # 유효슈팅
H28_4 = (myform.get_text('i').split('i')[10])
A28_4 = (myform.get_text('i').split('i')[12]) # 파울
H28_5 = (myform.get_text('i').split('i')[13])
A28_5 = (myform.get_text('i').split('i')[15]) # 경고
H28_6 = (myform.get_text('i').split('i')[16])
A28_6 = (myform.get_text('i').split('i')[18]) # 퇴장
H28_7 = (myform.get_text('i').split('i')[19])
A28_7 = (myform.get_text('i').split('i')[22]) #퇴장(경고누적)
H28_8 = (myform.get_text('i').split('i')[23])
A28_8 = (myform.get_text('i').split('i')[25]) # 코너킥
H28_9 = (myform.get_text('i').split('i')[26])
A28_9 = (myform.get_text('i').split('i')[28]) # 프리킥
H28_10 = (myform.get_text('i').split('i')[29])
A28_10 = (myform.get_text('i').split('i')[31]) # 오프사이드
 # 23라운드 홈팀 인천 원정팀 서울 데이터

# %%
url_move(seoul_list[28])
btn = chrome.find_element(by='xpath', value='/html/body/div[2]/div/ul/li[2]')
btn.click()
time.sleep(1)
response_1 = chrome.page_source
number= BeautifulSoup(response_1).find('div', {'class':'formation'}).text.split()
# 왼쪽 홈팀 오른쪽 원정팀
Havg_29 = avg(number)[0]
Aavg_29 = avg(number)[1]
Havg_29
Aavg_29
response_1 = chrome.page_source
score= BeautifulSoup(response_1).find('div', {'class':'score campton'})
S29_1 = score.text[0:1]
S29_2 = score.text[2:3]
response_2 = chrome.page_source
myform = BeautifulSoup(response_2).find('div', {'class':'btn-cont'})
H29_1 = (myform.get_text('i').split('i')[1])
A29_1 = (myform.get_text('i').split('i')[3]) #점유율
H29_2 = (myform.get_text('i').split('i')[4])
A29_2 = (myform.get_text('i').split('i')[6]) #슈팅
H29_3 = (myform.get_text('i').split('i')[7])
A29_3 = (myform.get_text('i').split('i')[9]) # 유효슈팅
H29_4 = (myform.get_text('i').split('i')[10])
A29_4 = (myform.get_text('i').split('i')[12]) # 파울
H29_5 = (myform.get_text('i').split('i')[13])
A29_5 = (myform.get_text('i').split('i')[15]) # 경고
H29_6 = (myform.get_text('i').split('i')[16])
A29_6 = (myform.get_text('i').split('i')[18]) # 퇴장
H29_7 = (myform.get_text('i').split('i')[19])
A29_7 = (myform.get_text('i').split('i')[22]) #퇴장(경고누적)
H29_8 = (myform.get_text('i').split('i')[23])
A29_8 = (myform.get_text('i').split('i')[25]) # 코너킥
H29_9 = (myform.get_text('i').split('i')[26])
A29_9 = (myform.get_text('i').split('i')[28]) # 프리킥
H29_10 = (myform.get_text('i').split('i')[29])
A29_10 = (myform.get_text('i').split('i')[31]) # 오프사이드
 # 29라운드 홈팀 서울 원정팀 수원 데이터

# %%
url_move(seoul_list[29])
btn = chrome.find_element(by='xpath', value='/html/body/div[2]/div/ul/li[2]')
btn.click()
time.sleep(1)
response_1 = chrome.page_source
number= BeautifulSoup(response_1).find('div', {'class':'formation'}).text.split()
# 왼쪽 홈팀 오른쪽 원정팀
Havg_30 = avg(number)[0]
Aavg_30 = avg(number)[1]
Havg_30
Aavg_30
response_1 = chrome.page_source
score= BeautifulSoup(response_1).find('div', {'class':'score campton'})
S30_1 = score.text[0:1]
S30_2 = score.text[2:3]
response_2 = chrome.page_source
myform = BeautifulSoup(response_2).find('div', {'class':'btn-cont'})
H30_1 = (myform.get_text('i').split('i')[1])
A30_1 = (myform.get_text('i').split('i')[3]) #점유율
H30_2 = (myform.get_text('i').split('i')[4])
A30_2 = (myform.get_text('i').split('i')[6]) #슈팅
H30_3 = (myform.get_text('i').split('i')[7])
A30_3 = (myform.get_text('i').split('i')[9]) # 유효슈팅
H30_4 = (myform.get_text('i').split('i')[10])
A30_4 = (myform.get_text('i').split('i')[12]) # 파울
H30_5 = (myform.get_text('i').split('i')[13])
A30_5 = (myform.get_text('i').split('i')[15]) # 경고
H30_6 = (myform.get_text('i').split('i')[16])
A30_6 = (myform.get_text('i').split('i')[18]) # 퇴장
H30_7 = (myform.get_text('i').split('i')[19])
A30_7 = (myform.get_text('i').split('i')[22]) #퇴장(경고누적)
H30_8 = (myform.get_text('i').split('i')[23])
A30_8 = (myform.get_text('i').split('i')[25]) # 코너킥
H30_9 = (myform.get_text('i').split('i')[26])
A30_9 = (myform.get_text('i').split('i')[28]) # 프리킥
H30_10 = (myform.get_text('i').split('i')[29])
A30_10 = (myform.get_text('i').split('i')[31]) # 오프사이드
 # 30라운드  홈팀 전북 원정팀 서울 데이터

# %%
url_move(seoul_list[30])
btn = chrome.find_element(by='xpath', value='/html/body/div[2]/div/ul/li[2]')
btn.click()
time.sleep(1)
response_1 = chrome.page_source
number= BeautifulSoup(response_1).find('div', {'class':'formation'}).text.split()
# 왼쪽 홈팀 오른쪽 원정팀
Havg_31 = avg(number)[0]
Aavg_31 = avg(number)[1]
Havg_31
Aavg_31
response_1 = chrome.page_source
score= BeautifulSoup(response_1).find('div', {'class':'score campton'})
S31_1 = score.text[0:1]
S31_2 = score.text[2:3]
response_2 = chrome.page_source
myform = BeautifulSoup(response_2).find('div', {'class':'btn-cont'})
H31_1 = (myform.get_text('i').split('i')[1])
A31_1 = (myform.get_text('i').split('i')[3]) #점유율
H31_2 = (myform.get_text('i').split('i')[4])
A31_2 = (myform.get_text('i').split('i')[6]) #슈팅
H31_3 = (myform.get_text('i').split('i')[7])
A31_3 = (myform.get_text('i').split('i')[9]) # 유효슈팅
H31_4 = (myform.get_text('i').split('i')[10])
A31_4 = (myform.get_text('i').split('i')[12]) # 파울
H31_5 = (myform.get_text('i').split('i')[13])
A31_5 = (myform.get_text('i').split('i')[15]) # 경고
H31_6 = (myform.get_text('i').split('i')[16])
A31_6 = (myform.get_text('i').split('i')[18]) # 퇴장
H31_7 = (myform.get_text('i').split('i')[19])
A31_7 = (myform.get_text('i').split('i')[22]) #퇴장(경고누적)
H31_8 = (myform.get_text('i').split('i')[23])
A31_8 = (myform.get_text('i').split('i')[25]) # 코너킥
H31_9 = (myform.get_text('i').split('i')[26])
A31_9 = (myform.get_text('i').split('i')[28]) # 프리킥
H31_10 = (myform.get_text('i').split('i')[29])
A31_10 = (myform.get_text('i').split('i')[31]) # 오프사이드
 # 31라운드 홈팀 서울 원정팀 수원FC 데이터

# %%
url_move(seoul_list[31])
btn = chrome.find_element(by='xpath', value='/html/body/div[2]/div/ul/li[2]')
btn.click()
time.sleep(1)
response_1 = chrome.page_source
number= BeautifulSoup(response_1).find('div', {'class':'formation'}).text.split()
# 왼쪽 홈팀 오른쪽 원정팀
Havg_32 = avg(number)[0]
Aavg_32 = avg(number)[1]
Havg_32
Aavg_32
response_1 = chrome.page_source
score= BeautifulSoup(response_1).find('div', {'class':'score campton'})
S32_1 = score.text[0:1]
S32_2 = score.text[2:3]
response_2 = chrome.page_source
myform = BeautifulSoup(response_2).find('div', {'class':'btn-cont'})
H32_1 = (myform.get_text('i').split('i')[1])
A32_1 = (myform.get_text('i').split('i')[3]) #점유율
H32_2 = (myform.get_text('i').split('i')[4])
A32_2 = (myform.get_text('i').split('i')[6]) #슈팅
H32_3 = (myform.get_text('i').split('i')[7])
A32_3 = (myform.get_text('i').split('i')[9]) # 유효슈팅
H32_4 = (myform.get_text('i').split('i')[10])
A32_4 = (myform.get_text('i').split('i')[12]) # 파울
H32_5 = (myform.get_text('i').split('i')[13])
A32_5 = (myform.get_text('i').split('i')[15]) # 경고
H32_6 = (myform.get_text('i').split('i')[16])
A32_6 = (myform.get_text('i').split('i')[18]) # 퇴장
H32_7 = (myform.get_text('i').split('i')[19])
A32_7 = (myform.get_text('i').split('i')[22]) #퇴장(경고누적)
H32_8 = (myform.get_text('i').split('i')[23])
A32_8 = (myform.get_text('i').split('i')[25]) # 코너킥
H32_9 = (myform.get_text('i').split('i')[26])
A32_9 = (myform.get_text('i').split('i')[28]) # 프리킥
H32_10 = (myform.get_text('i').split('i')[29])
A32_10 = (myform.get_text('i').split('i')[31]) # 오프사이드
 # 32라운드  홈팀 서울 원정팀 강원 데이터

# %%
url_move(seoul_list[32])
btn = chrome.find_element(by='xpath', value='/html/body/div[2]/div/ul/li[2]')
btn.click()
time.sleep(1)
response_1 = chrome.page_source
number= BeautifulSoup(response_1).find('div', {'class':'formation'}).text.split()
# 왼쪽 홈팀 오른쪽 원정팀
Havg_33 = avg(number)[0]
Aavg_33 = avg(number)[1]
Havg_33
Aavg_33
response_1 = chrome.page_source
score= BeautifulSoup(response_1).find('div', {'class':'score campton'})
S33_1 = score.text[0:1]
S33_2 = score.text[2:3]
response_2 = chrome.page_source
myform = BeautifulSoup(response_2).find('div', {'class':'btn-cont'})
H33_1 = (myform.get_text('i').split('i')[1])
A33_1 = (myform.get_text('i').split('i')[3]) #점유율
H33_2 = (myform.get_text('i').split('i')[4])
A33_2 = (myform.get_text('i').split('i')[6]) #슈팅
H33_3 = (myform.get_text('i').split('i')[7])
A33_3 = (myform.get_text('i').split('i')[9]) # 유효슈팅
H33_4 = (myform.get_text('i').split('i')[10])
A33_4 = (myform.get_text('i').split('i')[12]) # 파울
H33_5 = (myform.get_text('i').split('i')[13])
A33_5 = (myform.get_text('i').split('i')[15]) # 경고
H33_6 = (myform.get_text('i').split('i')[16])
A33_6 = (myform.get_text('i').split('i')[18]) # 퇴장
H33_7 = (myform.get_text('i').split('i')[19])
A33_7 = (myform.get_text('i').split('i')[22]) #퇴장(경고누적)
H33_8 = (myform.get_text('i').split('i')[23])
A33_8 = (myform.get_text('i').split('i')[25]) # 코너킥
H33_9 = (myform.get_text('i').split('i')[26])
A33_9 = (myform.get_text('i').split('i')[28]) # 프리킥
H33_10 = (myform.get_text('i').split('i')[29])
A33_10 = (myform.get_text('i').split('i')[31]) # 오프사이드
 # 33라운드 홈팀 대구 원정팀 서울 데이터

# %%
url_move(seoul_list[33])
btn = chrome.find_element(by='xpath', value='/html/body/div[2]/div/ul/li[2]')
btn.click()
time.sleep(1)
response_1 = chrome.page_source
number= BeautifulSoup(response_1).find('div', {'class':'formation'}).text.split()
# 왼쪽 홈팀 오른쪽 원정팀
Havg_34 = avg(number)[0]
Aavg_34 = avg(number)[1]
Havg_34
Aavg_34
response_1 = chrome.page_source
score= BeautifulSoup(response_1).find('div', {'class':'score campton'})
S34_1 = score.text[0:1]
S34_2 = score.text[2:3]
response_2 = chrome.page_source
myform = BeautifulSoup(response_2).find('div', {'class':'btn-cont'})
H34_1 = (myform.get_text('i').split('i')[1])
A34_1 = (myform.get_text('i').split('i')[3]) #점유율
H34_2 = (myform.get_text('i').split('i')[4])
A34_2 = (myform.get_text('i').split('i')[6]) #슈팅
H34_3 = (myform.get_text('i').split('i')[7])
A34_3 = (myform.get_text('i').split('i')[9]) # 유효슈팅
H34_4 = (myform.get_text('i').split('i')[10])
A34_4 = (myform.get_text('i').split('i')[12]) # 파울
H34_5 = (myform.get_text('i').split('i')[13])
A34_5 = (myform.get_text('i').split('i')[15]) # 경고
H34_6 = (myform.get_text('i').split('i')[16])
A34_6 = (myform.get_text('i').split('i')[18]) # 퇴장
H34_7 = (myform.get_text('i').split('i')[19])
A34_7 = (myform.get_text('i').split('i')[22]) #퇴장(경고누적)
H34_8 = (myform.get_text('i').split('i')[23])
A34_8 = (myform.get_text('i').split('i')[25]) # 코너킥
H34_9 = (myform.get_text('i').split('i')[26])
A34_9 = (myform.get_text('i').split('i')[28]) # 프리킥
H34_10 = (myform.get_text('i').split('i')[29])
A34_10 = (myform.get_text('i').split('i')[31]) # 오프사이드
 # 34라운드 홈팀 서울 원정팀 대구 데이터

# %%
url_move(seoul_list[34])
btn = chrome.find_element(by='xpath', value='/html/body/div[2]/div/ul/li[2]')
btn.click()
time.sleep(1)
response_1 = chrome.page_source
number= BeautifulSoup(response_1).find('div', {'class':'formation'}).text.split()
# 왼쪽 홈팀 오른쪽 원정팀
Havg_35 = avg(number)[0]
Aavg_35 = avg(number)[1]
Havg_35
Aavg_35
response_1 = chrome.page_source
score= BeautifulSoup(response_1).find('div', {'class':'score campton'})
S35_1 = score.text[0:1]
S35_2 = score.text[2:3]
response_2 = chrome.page_source
myform = BeautifulSoup(response_2).find('div', {'class':'btn-cont'})
H35_1 = (myform.get_text('i').split('i')[1])
A35_1 = (myform.get_text('i').split('i')[3]) #점유율
H35_2 = (myform.get_text('i').split('i')[4])
A35_2 = (myform.get_text('i').split('i')[6]) #슈팅
H35_3 = (myform.get_text('i').split('i')[7])
A35_3 = (myform.get_text('i').split('i')[9]) # 유효슈팅
H35_4 = (myform.get_text('i').split('i')[10])
A35_4 = (myform.get_text('i').split('i')[12]) # 파울
H35_5 = (myform.get_text('i').split('i')[13])
A35_5 = (myform.get_text('i').split('i')[15]) # 경고
H35_6 = (myform.get_text('i').split('i')[16])
A35_6 = (myform.get_text('i').split('i')[18]) # 퇴장
H35_7 = (myform.get_text('i').split('i')[19])
A35_7 = (myform.get_text('i').split('i')[22]) #퇴장(경고누적)
H35_8 = (myform.get_text('i').split('i')[23])
A35_8 = (myform.get_text('i').split('i')[25]) # 코너킥
H35_9 = (myform.get_text('i').split('i')[26])
A35_9 = (myform.get_text('i').split('i')[28]) # 프리킥
H35_10 = (myform.get_text('i').split('i')[29])
A35_10 = (myform.get_text('i').split('i')[31]) # 오프사이드
 # 35라운드 홈팀 수원 원정팀 서울 데이터

# %%
url_move(seoul_list[35])
btn = chrome.find_element(by='xpath', value='/html/body/div[2]/div/ul/li[2]')
btn.click()
time.sleep(1)
response_1 = chrome.page_source
number= BeautifulSoup(response_1).find('div', {'class':'formation'}).text.split()
# 왼쪽 홈팀 오른쪽 원정팀
Havg_36 = avg(number)[0]
Aavg_36 = avg(number)[1]
Havg_36
Aavg_36
response_1 = chrome.page_source
score= BeautifulSoup(response_1).find('div', {'class':'score campton'})
S36_1 = score.text[0:1]
S36_2 = score.text[2:3]
response_2 = chrome.page_source
myform = BeautifulSoup(response_2).find('div', {'class':'btn-cont'})
H36_1 = (myform.get_text('i').split('i')[1])
A36_1 = (myform.get_text('i').split('i')[3]) #점유율
H36_2 = (myform.get_text('i').split('i')[4])
A36_2 = (myform.get_text('i').split('i')[6]) #슈팅
H36_3 = (myform.get_text('i').split('i')[7])
A36_3 = (myform.get_text('i').split('i')[9]) # 유효슈팅
H36_4 = (myform.get_text('i').split('i')[10])
A36_4 = (myform.get_text('i').split('i')[12]) # 파울
H36_5 = (myform.get_text('i').split('i')[13])
A36_5 = (myform.get_text('i').split('i')[15]) # 경고
H36_6 = (myform.get_text('i').split('i')[16])
A36_6 = (myform.get_text('i').split('i')[18]) # 퇴장
H36_7 = (myform.get_text('i').split('i')[19])
A36_7 = (myform.get_text('i').split('i')[22]) #퇴장(경고누적)
H36_8 = (myform.get_text('i').split('i')[23])
A36_8 = (myform.get_text('i').split('i')[25]) # 코너킥
H36_9 = (myform.get_text('i').split('i')[26])
A36_9 = (myform.get_text('i').split('i')[28]) # 프리킥
H36_10 = (myform.get_text('i').split('i')[29])
A36_10 = (myform.get_text('i').split('i')[31]) # 오프사이드
 # 36라운드 홈팀 서울 원정팀 김천 데이터

# %%
url_move(seoul_list[36])
btn = chrome.find_element(by='xpath', value='/html/body/div[2]/div/ul/li[2]')
btn.click()
time.sleep(1)
response_1 = chrome.page_source
number= BeautifulSoup(response_1).find('div', {'class':'formation'}).text.split()
# 왼쪽 홈팀 오른쪽 원정팀
Havg_37 = avg(number)[0]
Aavg_37 = avg(number)[1]
Havg_37
Aavg_37
response_1 = chrome.page_source
score= BeautifulSoup(response_1).find('div', {'class':'score campton'})
S37_1 = score.text[0:1]
S37_2 = score.text[2:3]
response_2 = chrome.page_source
myform = BeautifulSoup(response_2).find('div', {'class':'btn-cont'})
H37_1 = (myform.get_text('i').split('i')[1])
A37_1 = (myform.get_text('i').split('i')[3]) #점유율
H37_2 = (myform.get_text('i').split('i')[4])
A37_2 = (myform.get_text('i').split('i')[6]) #슈팅
H37_3 = (myform.get_text('i').split('i')[7])
A37_3 = (myform.get_text('i').split('i')[9]) # 유효슈팅
H37_4 = (myform.get_text('i').split('i')[10])
A37_4 = (myform.get_text('i').split('i')[12]) # 파울
H37_5 = (myform.get_text('i').split('i')[13])
A37_5 = (myform.get_text('i').split('i')[15]) # 경고
H37_6 = (myform.get_text('i').split('i')[16])
A37_6 = (myform.get_text('i').split('i')[18]) # 퇴장
H37_7 = (myform.get_text('i').split('i')[19])
A37_7 = (myform.get_text('i').split('i')[22]) #퇴장(경고누적)
H37_8 = (myform.get_text('i').split('i')[23])
A37_8 = (myform.get_text('i').split('i')[25]) # 코너킥
H37_9 = (myform.get_text('i').split('i')[26])
A37_9 = (myform.get_text('i').split('i')[28]) # 프리킥
H37_10 = (myform.get_text('i').split('i')[29])
A37_10 = (myform.get_text('i').split('i')[31]) # 오프사이드
 # 37라운드 홈팀 서울 원정팀 성남 데이터

# %%
url_move(seoul_list[37])
btn = chrome.find_element(by='xpath', value='/html/body/div[2]/div/ul/li[2]')
btn.click()
time.sleep(1)
response_1 = chrome.page_source
number= BeautifulSoup(response_1).find('div', {'class':'formation'}).text.split()
# 왼쪽 홈팀 오른쪽 원정팀
Havg_38 = avg(number)[0]
Aavg_38 = avg(number)[1]
Havg_38
Aavg_38
response_1 = chrome.page_source
score= BeautifulSoup(response_1).find('div', {'class':'score campton'})
S38_1 = score.text[0:1]
S38_2 = score.text[2:3]
response_2 = chrome.page_source
myform = BeautifulSoup(response_2).find('div', {'class':'btn-cont'})
H38_1 = (myform.get_text('i').split('i')[1])
A38_1 = (myform.get_text('i').split('i')[3]) #점유율
H38_2 = (myform.get_text('i').split('i')[4])
A38_2 = (myform.get_text('i').split('i')[6]) #슈팅
H38_3 = (myform.get_text('i').split('i')[7])
A38_3 = (myform.get_text('i').split('i')[9]) # 유효슈팅
H38_4 = (myform.get_text('i').split('i')[10])
A38_4 = (myform.get_text('i').split('i')[12]) # 파울
H38_5 = (myform.get_text('i').split('i')[13])
A38_5 = (myform.get_text('i').split('i')[15]) # 경고
H38_6 = (myform.get_text('i').split('i')[16])
A38_6 = (myform.get_text('i').split('i')[18]) # 퇴장
H38_7 = (myform.get_text('i').split('i')[19])
A38_7 = (myform.get_text('i').split('i')[22]) #퇴장(경고누적)
H38_8 = (myform.get_text('i').split('i')[23])
A38_8 = (myform.get_text('i').split('i')[25]) # 코너킥
H38_9 = (myform.get_text('i').split('i')[26])
A38_9 = (myform.get_text('i').split('i')[28]) # 프리킥
H38_10 = (myform.get_text('i').split('i')[29])
A38_10 = (myform.get_text('i').split('i')[31]) # 오프사이드
 # 38라운드 #홈팀 수원FC 원정팀 서울 데이터

# %%
df = pd.DataFrame([[H1_1,H1_2,H1_3,H1_4,H1_5,H1_6,H1_7,H1_8,H1_9,H1_10,S1_1,Havg_1],[A1_1,A1_2,A1_3,A1_4,A1_5,A1_6,A1_7,A1_8,A1_9,A1_10,S1_2,Aavg_1],[H2_1,H2_2,H2_3,H2_4,H2_5,H2_6,H2_7,H2_8,H2_9,H2_10,S2_1,Havg_2],[A2_1,A2_2,A2_3,A2_4,A2_5,A2_6,A2_7,A2_8,A2_9,A2_10,S2_2,Aavg_2],[H3_1,H3_2,H3_3,H3_4,H3_5,H3_6,H3_7,H3_8,H3_9,H3_10,S3_1,Havg_3],[A3_1,A3_2,A3_3,A3_4,A3_5,A3_6,A3_7,A3_8,A3_9,A3_10,S3_2,Aavg_3],[H4_1,H4_2,H4_3,H4_4,H4_5,H4_6,H4_7,H4_8,H4_9,H4_10,S4_1,Havg_4],[A4_1,A4_2,A4_3,A4_4,A4_5,A4_6,A4_7,A4_8,A4_9,A4_10,S4_2,Aavg_4],[H5_1,H5_2,H5_3,H5_4,H5_5,H5_6,H5_7,H5_8,H5_9,H5_10,S5_1,Havg_5],[A5_1,A5_2,A5_3,A5_4,A5_5,A5_6,A5_7,A5_8,A5_9,A5_10,S5_2,Aavg_5],[H6_1,H6_2,H6_3,H6_4,H6_5,H6_6,H6_7,H6_8,H6_9,H6_10,S6_1,Havg_6],[A6_1,A6_2,A6_3,A6_4,A6_5,A6_6,A6_7,A6_8,A6_9,A6_10,S6_2,Aavg_6],[H7_1,H7_2,H7_3,H7_4,H7_5,H7_6,H7_7,H7_8,H7_9,H7_10,S7_1,Havg_7],[A7_1,A7_2,A7_3,A7_4,A7_5,A7_6,A7_7,A7_8,A7_9,A7_10,S7_2,Aavg_7],[H8_1,H8_2,H8_3,H8_4,H8_5,H8_6,H8_7,H8_8,H8_9,H8_10,S8_1,Havg_8],[A8_1,A8_2,A8_3,A8_4,A8_5,A8_6,A8_7,A8_8,A8_9,A8_10,S8_2,Aavg_8],[H9_1,H9_2,H9_3,H9_4,H9_5,H9_6,H9_7,H9_8,H9_9,H9_10,S9_1,Havg_9],[A9_1,A9_2,A9_3,A9_4,A9_5,A9_6,A9_7,A9_8,A9_9,A9_10,S3_2,Aavg_9],[H10_1,H10_2,H10_3,H10_4,H10_5,H10_6,H10_7,H10_8,H10_9,H10_10,S10_1,Havg_10],[A10_1,A10_2,A10_3,A10_4,A10_5,A10_6,A10_7,A10_8,A10_9,A10_10,S10_2,Aavg_10],[H11_1,H11_2,H11_3,H11_4,H11_5,H11_6,H11_7,H11_8,H11_9,H11_10,S11_1,Havg_11],[A11_1,A11_2,A11_3,A11_4,A11_5,A11_6,A11_7,A11_8,A11_9,A11_10,S11_2,Aavg_11],[H12_1,H12_2,H12_3,H12_4,H12_5,H12_6,H12_7,H12_8,H12_9,H12_10,S12_1,Havg_12],[A12_1,A12_2,A12_3,A12_4,A12_5,A12_6,A12_7,A12_8,A12_9,A12_10,S12_2,Aavg_12],[H13_1,H13_2,H13_3,H13_4,H13_5,H13_6,H13_7,H13_8,H13_9,H13_10,S13_1,Havg_13],[A13_1,A13_2,A13_3,A13_4,A13_5,A13_6,A13_7,A13_8,A13_9,A13_10,S13_2,Aavg_13],[H14_1,H14_2,H14_3,H14_4,H14_5,H14_6,H14_7,H14_8,H14_9,H14_10,S14_1,Havg_14],[A14_1,A14_2,A14_3,A14_4,A14_5,A14_6,A14_7,A14_8,A14_9,A14_10,S14_2,Aavg_14],[H15_1,H15_2,H15_3,H15_4,H15_5,H15_6,H15_7,H15_8,H15_9,H15_10,S15_1,Havg_15],[A15_1,A15_2,A15_3,A15_4,A15_5,A15_6,A15_7,A15_8,A15_9,A15_10,S15_2,Aavg_15],[H16_1,H16_2,H16_3,H16_4,H16_5,H16_6,H16_7,H16_8,H16_9,H16_10,S16_1,Havg_16],[A16_1,A16_2,A16_3,A16_4,A16_5,A16_6,A16_7,A16_8,A16_9,A16_10,S16_2,Aavg_16],[H17_1,H17_2,H17_3,H17_4,H17_5,H17_6,H17_7,H17_8,H17_9,H17_10,S17_1,Havg_17],[A17_1,A17_2,A17_3,A17_4,A17_5,A17_6,A17_7,A17_8,A17_9,A17_10,S17_2,Aavg_17],[H18_1,H18_2,H18_3,H18_4,H18_5,H18_6,H18_7,H18_8,H18_9,H18_10,S18_1,Havg_18],[A18_1,A18_2,A18_3,A18_4,A18_5,A18_6,A18_7,A18_8,A18_9,A18_10,S18_2,Aavg_18],[H19_1,H19_2,H19_3,H19_4,H19_5,H19_6,H19_7,H19_8,H19_9,H19_10,S19_1,Havg_19],[A19_1,A19_2,A19_3,A19_4,A19_5,A19_6,A19_7,A19_8,A19_9,A19_10,S19_2,Aavg_19],[H20_1,H20_2,H20_3,H20_4,H20_5,H20_6,H20_7,H20_8,H20_9,H20_10,S20_1,Havg_20],[A20_1,A20_2,A20_3,A20_4,A20_5,A20_6,A20_7,A20_8,A20_9,A20_10,S20_2,Aavg_20],[H21_1,H21_2,H21_3,H21_4,H21_5,H21_6,H21_7,H21_8,H21_9,H21_10,S21_1,Havg_21],[A21_1,A21_2,A21_3,A21_4,A21_5,A21_6,A21_7,A21_8,A21_9,A21_10,S21_2,Aavg_21],[H22_1,H22_2,H22_3,H22_4,H22_5,H22_6,H22_7,H22_8,H22_9,H22_10,S22_1,Havg_22],[A22_1,A22_2,A22_3,A22_4,A22_5,A22_6,A22_7,A22_8,A22_9,A22_10,S22_2,Aavg_22],[H23_1,H23_2,H23_3,H23_4,H23_5,H23_6,H23_7,H23_8,H23_9,H23_10,S23_1,Havg_23],[A23_1,A23_2,A23_3,A23_4,A23_5,A23_6,A23_7,A23_8,A23_9,A23_10,S23_2,Aavg_23],[H24_1,H24_2,H24_3,H24_4,H24_5,H24_6,H24_7,H24_8,H24_9,H24_10,S24_1,Havg_24],[A24_1,A24_2,A24_3,A24_4,A24_5,A24_6,A24_7,A24_8,A24_9,A24_10,S24_2,Aavg_24],[H25_1,H25_2,H25_3,H25_4,H25_5,H25_6,H25_7,H25_8,H25_9,H25_10,S25_1,Havg_25],[A25_1,A25_2,A25_3,A25_4,A25_5,A25_6,A25_7,A25_8,A25_9,A25_10,S25_2,Aavg_25],[H26_1,H26_2,H26_3,H26_4,H26_5,H26_6,H26_7,H26_8,H26_9,H26_10,S26_1,Havg_26],[A26_1,A26_2,A26_3,A26_4,A26_5,A26_6,A26_7,A26_8,A26_9,A26_10,S26_2,Aavg_26],[H27_1,H27_2,H27_3,H27_4,H27_5,H27_6,H27_7,H27_8,H27_9,H27_10,S27_1,Havg_27],[A27_1,A27_2,A27_3,A27_4,A27_5,A27_6,A27_7,A27_8,A27_9,A27_10,S27_2,Aavg_27],[H28_1,H28_2,H28_3,H28_4,H28_5,H28_6,H28_7,H28_8,H28_9,H28_10,S28_1,Havg_28],[A28_1,A28_2,A28_3,A28_4,A28_5,A28_6,A28_7,A28_8,A28_9,A28_10,S28_2,Aavg_28],[H29_1,H29_2,H29_3,H29_4,H29_5,H29_6,H29_7,H29_8,H29_9,H29_10,S29_1,Havg_29],[A29_1,A29_2,A29_3,A29_4,A29_5,A29_6,A29_7,A29_8,A29_9,A29_10,S29_2,Aavg_29],[H30_1,H30_2,H30_3,H30_4,H30_5,H30_6,H30_7,H30_8,H30_9,H30_10,S30_1,Havg_30],[A30_1,A30_2,A30_3,A30_4,A30_5,A30_6,A30_7,A30_8,A30_9,A30_10,S30_2,Aavg_30],[H31_1,H31_2,H31_3,H31_4,H31_5,H31_6,H31_7,H31_8,H31_9,H31_10,S31_1,Havg_31],[A31_1,A31_2,A31_3,A31_4,A31_5,A31_6,A31_7,A31_8,A31_9,A31_10,S31_2,Aavg_31],[H32_1,H32_2,H32_3,H32_4,H32_5,H32_6,H32_7,H32_8,H32_9,H32_10,S32_1,Havg_32],[A32_1,A32_2,A32_3,A32_4,A32_5,A32_6,A32_7,A32_8,A32_9,A32_10,S32_2,Aavg_32],[H33_1,H33_2,H33_3,H33_4,H33_5,H33_6,H33_7,H33_8,H33_9,H33_10,S33_1,Havg_33],[A33_1,A33_2,A33_3,A33_4,A33_5,A33_6,A33_7,A33_8,A33_9,A33_10,S33_2,Aavg_33],[H34_1,H34_2,H34_3,H34_4,H34_5,H34_6,H34_7,H34_8,H34_9,H34_10,S34_1,Havg_34],[A34_1,A34_2,A34_3,A34_4,A34_5,A34_6,A34_7,A34_8,A34_9,A34_10,S34_2,Aavg_34],[H35_1,H35_2,H35_3,H35_4,H35_5,H35_6,H35_7,H35_8,H35_9,H35_10,S35_1,Havg_35],[A35_1,A35_2,A35_3,A35_4,A35_5,A35_6,A35_7,A35_8,A35_9,A35_10,S35_2,Aavg_35],[H36_1,H36_2,H36_3,H36_4,H36_5,H36_6,H36_7,H36_8,H36_9,H36_10,S36_1,Havg_36],[A36_1,A36_2,A36_3,A36_4,A36_5,A36_6,A36_7,A36_8,A36_9,A36_10,S36_2,Aavg_36],[H37_1,H37_2,H37_3,H37_4,H37_5,H37_6,H37_7,H37_8,H37_9,H37_10,S37_1,Havg_37],[A37_1,A37_2,A37_3,A37_4,A37_5,A37_6,A37_7,A37_8,A37_9,A37_10,S37_2,Aavg_37],[H38_1,H38_2,H38_3,H38_4,H38_5,H38_6,H38_7,H38_8,H38_9,H38_10,S38_1,Havg_38],[A38_1,A38_2,A38_3,A38_4,A38_5,A38_6,A38_7,A38_8,A38_9,A38_10,S38_2,Aavg_38]],index=["대구","FC서울","인천","FC서울","성남","FC서울","성남","FC서울","김천","FC서울","울산","FC서울","FC서울","제주","포항","FC서울","FC서울","강원","FC서울","수원","전북","FC서울","FC서울","수원FC","FC서울","포항","강원","FC서울","성남","FC서울","김천","수원","FC서울","FC서울","울산","FC서울","인천","FC서울","제주","FC서울","FC서울","전북","수원FC","FC서울","포항","FC서울","울산","FC서울","FC서울","제주","김천","FC서울","FC서울","성남","인천","FC서울","FC서울","수원","전북","FC서울","FC서울","수원FC","FC서울","강원","대구","FC서울","FC서울","대구","수원","FC서울","FC서울","김천","FC서울","성남","수원FC","FC서울"],columns=['점유율','슈팅','유효슈팅','파울','경고','퇴장','퇴장(경고누적)','코너킥','프리킥','오프사이드','경기결과(스코어)','평점'])
df
# Out:
#         점유율  슈팅 유효슈팅  파울 경고 퇴장 퇴장(경고누적) 코너킥 프리킥 오프사이드 경기결과(스코어)   평점
# 대구    38.67   8    2  17  4  0        0   3  22     5         0  5.7
# FC서울  61.32  11    4  11  2  0        0   3  14     3         2  7.1
# 인천    33.13   8    5  10  3  0        0   4  14     4         1  7.1
# FC서울  66.87  11    7  13  2  0        0   5  13     0         1  6.9
# 성남    23.50   3    3   9  1  0        0   2  11     2         0  6.7
# ...     ...  ..  ...  .. .. ..      ...  ..  ..   ...       ...  ...
# 김천    64.93  11    6   9  0  0        0   3  12     3         1  6.9
# FC서울  58.56   9    4   8  1  0        0   6  11     3         0  6.7
# 성남    41.44   7    3  10  0  0        0   5  14     4         1  6.8
# 수원FC  54.53  10    5   9  0  0        0   5  10     1         0  6.5
# FC서울  45.47   8    6  13  2  0        0   3  15     2         2  7.1
#
# [76 rows x 12 columns]

# %%
df.to_csv('HSY.csv')
